# %% [markdown]
# # LangSmith

# %% [markdown]
# ### Problem Statement
#
# Build a **simple workflow using Python and LangSmith** that takes a user input and generates a response.
#
# The workflow should:
#
# 1. Accept a user input.
# 2. Process the input.
# 3. Generate a response based on the input.
# 4. Return the response to the user.
# 5. Use **LangSmith** to trace and monitor the workflow execution.
#
# **Workflow:**
#
# ```text
# START → Process Input → Generate Response → END

# %% [markdown]
# For LangSmith API keys linked to multiple workspaces, set the LANGSMITH_WORKSPACE_ID environment variable to specify which workspace to use.
#
#
# 1) export LANGSMITH_TRACING=true
# 2) export LANGSMITH_API_KEY=<your-api-key>
# 3) export LANGSMITH_WORKSPACE_ID=<wd-1>
# 4) export LANGSMITH_PROJECT="Practice Project"
# 5) export LANGSMITH_ENDPOINT="https://api.smith.langchain.com"

# %%
# !pip install langsmith

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5.4-mini")

response = llm.invoke("What is LangSmith?")

print(response.content)
# Out:
# LangSmith is a **tooling platform from LangChain** for **building, testing, debugging, and monitoring LLM applications**.
#
# In practice, it helps you:
#
# - **Trace** LLM calls and chains end-to-end
# - **Debug** prompts, outputs, and agent behavior
# - **Evaluate** model or app quality with datasets and metrics
# - **Monitor** production usage, latency, errors, and regressions
# - **Compare** different prompts, models, or workflows
#
# Think of it as an **observability and evaluation layer for AI apps**.
#
# ### Typical use cases
# - Finding why an agent gave a bad answer
# - Testing prompt changes before deployment
# - Running evaluations on a dataset of examples
# - Tracking performance in production over time
#
# If you want, I can also explain:
# 1. how LangSmith differs from LangChain, or
# 2. how to use LangSmith in a simple Python app.
