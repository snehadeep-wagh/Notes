# %% [markdown]
# ### Vector Store and Database
#
# Vectore stores - FAISS, HNSW, Milvus, Pinecone, Weaviate, and Qdrant, ChromaDB are the vector store.
#
# In this we will implement using chromaDB

# %%
# !pip install chromadb tiktoken
# Out:
# ...
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    -------- ------------------------------- 5.0/23.5 MB 26.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 9.4/23.5 MB 25.5 MB/s eta 0:00:01
#    ------------------- -------------------- 11.3/23.5 MB 19.7 MB/s eta 0:00:01
#    --------------------- ------------------ 12.6/23.5 MB 15.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 13.9/23.5 MB 13.8 MB/s eta 0:00:01
#    -------------------------- ------------- 15.5/23.5 MB 12.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 17.3/23.5 MB 12.1 MB/s eta 0:00:01
#    -------------------------------- ------- 19.4/23.5 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------ --- 21.5/23.5 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  23.3/23.5 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 23.5/23.5 MB 11.3 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import ChatOpenEmbeddings
