# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: langchain in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 2)) (1.3.14)
# Requirement already satisfied: langchain-core in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: langchain-openai in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 6)) (1.3.5)
# Requirement already satisfied: openai in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 7)) (2.46.0)
# Requirement already satisfied: langchain-anthropic in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 10)) (1.4.8)
# Requirement already satisfied: langchain-google-genai in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 13)) (4.2.7)
# Requirement already satisfied: google-generativeai in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 14)) (0.8.6)
# Requirement already satisfied: langchain-huggingface in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 17)) (1.2.2)
# Requirement already satisfied: transformers in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 18)) (5.14.1)
# Requirement already satisfied: huggingface-hub in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 19)) (1.24.0)
# Requirement already satisfied: python-dotenv in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 22)) (1.1.0)
# Requirement already satisfied: numpy in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 25)) (2.1.3)
# Requirement already satisfied: scikit-learn in c:\users\snehd\anaconda3\lib\site-packages (from -r ../requirements.txt (line 26)) (1.6.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\snehd\anaconda3\lib\site-packages (from langchain->-r ../requirements.txt (line 2)) (1.2.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\snehd\anaconda3\lib\site-packages (from langchain->-r ../requirements.txt (line 2)) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-core->-r ../requirements.txt (line 3)) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-core->-r ../requirements.txt (line 3)) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-core->-r ../requirements.txt (line 3)) (0.10.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-core->-r ../requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-core->-r ../requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-core->-r ../requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-core->-r ../requirements.txt (line 3)) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-core->-r ../requirements.txt (line 3)) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\snehd\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->-r ../requirements.txt (line 3)) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\snehd\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\snehd\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\snehd\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\snehd\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\snehd\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\snehd\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\snehd\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\snehd\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\snehd\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r ../requirements.txt (line 3)) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in c:\users\snehd\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r ../requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\snehd\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r ../requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\snehd\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r ../requirements.txt (line 3)) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\snehd\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r ../requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\snehd\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r ../requirements.txt (line 3)) (0.23.0)
# Requirement already satisfied: certifi in c:\users\snehd\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\snehd\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: idna in c:\users\snehd\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\snehd\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r ../requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\snehd\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r ../requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\snehd\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r ../requirements.txt (line 2)) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\snehd\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r ../requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-openai->-r ../requirements.txt (line 6)) (0.13.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\snehd\anaconda3\lib\site-packages (from openai->-r ../requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: tqdm>4 in c:\users\snehd\anaconda3\lib\site-packages (from openai->-r ../requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: regex in c:\users\snehd\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai->-r ../requirements.txt (line 6)) (2026.7.19)
# Requirement already satisfied: anthropic<1.0.0,>=0.96.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-anthropic->-r ../requirements.txt (line 10)) (0.117.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\snehd\anaconda3\lib\site-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic->-r ../requirements.txt (line 10)) (0.18.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-google-genai->-r ../requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-google-genai->-r ../requirements.txt (line 13)) (2.12.1)
# Requirement already satisfied: google-auth<2.56.0,>=2.48.1 in c:\users\snehd\anaconda3\lib\site-packages (from google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r ../requirements.txt (line 13)) (2.55.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\snehd\anaconda3\lib\site-packages (from google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r ../requirements.txt (line 13)) (0.2.8)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\snehd\anaconda3\lib\site-packages (from google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r ../requirements.txt (line 13)) (44.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\snehd\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core->-r ../requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\snehd\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core->-r ../requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\snehd\anaconda3\lib\site-packages (from google-generativeai->-r ../requirements.txt (line 14)) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\snehd\anaconda3\lib\site-packages (from google-generativeai->-r ../requirements.txt (line 14)) (2.32.0)
# Requirement already satisfied: google-api-python-client in c:\users\snehd\anaconda3\lib\site-packages (from google-generativeai->-r ../requirements.txt (line 14)) (2.198.0)
# Requirement already satisfied: protobuf in c:\users\snehd\anaconda3\lib\site-packages (from google-generativeai->-r ../requirements.txt (line 14)) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\snehd\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai->-r ../requirements.txt (line 14)) (1.28.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\snehd\anaconda3\lib\site-packages (from google-api-core->google-generativeai->-r ../requirements.txt (line 14)) (1.75.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.41.0 in c:\users\snehd\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->-r ../requirements.txt (line 14)) (1.82.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.41.0 in c:\users\snehd\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->-r ../requirements.txt (line 14)) (1.71.2)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\snehd\anaconda3\lib\site-packages (from langchain-huggingface->-r ../requirements.txt (line 17)) (0.22.2)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in c:\users\snehd\anaconda3\lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 19)) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\snehd\anaconda3\lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 19)) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\snehd\anaconda3\lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 19)) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\snehd\anaconda3\lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 19)) (1.5.2)
# Requirement already satisfied: colorama in c:\users\snehd\anaconda3\lib\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub->-r ../requirements.txt (line 19)) (0.4.6)
# Requirement already satisfied: typer in c:\users\snehd\anaconda3\lib\site-packages (from transformers->-r ../requirements.txt (line 18)) (0.9.0)
# Requirement already satisfied: safetensors>=0.8.0 in c:\users\snehd\anaconda3\lib\site-packages (from transformers->-r ../requirements.txt (line 18)) (0.8.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\snehd\anaconda3\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 26)) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\snehd\anaconda3\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 26)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\snehd\anaconda3\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 26)) (3.5.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\snehd\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r ../requirements.txt (line 13)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\snehd\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r ../requirements.txt (line 13)) (2.21)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\snehd\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r ../requirements.txt (line 13)) (0.4.8)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\snehd\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai->-r ../requirements.txt (line 14)) (0.32.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\snehd\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai->-r ../requirements.txt (line 14)) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\snehd\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai->-r ../requirements.txt (line 14)) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\snehd\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai->-r ../requirements.txt (line 14)) (3.2.0)

# %%
from dotenv import load_dotenv
from langchain_openai import OpenAI
import os

# %%
load_dotenv()
# Out:
# True

# %%
v_model = "gpt-3.5-turbo-instruct"
v_temperature = 1.0

# %%
api_key = os.getenv("OPENAI_API_KEY1")

# %%
llm_model = OpenAI(
    model=v_model,
    temperature=v_temperature,
    api_key=api_key
)

# %%
# Chat message
msg = "What is the langchain."

# %%
res = llm_model.invoke(msg)

# %%
res
# Out:
# '\n\nThe term "langchain" does not have a commonly accepted definition. It could potentially refer to a blockchain-based platform or network for language-related applications or services, or it could be a made-up term with no specific meaning. Without further context, it is impossible to determine what is being referred to by "langchain."'
